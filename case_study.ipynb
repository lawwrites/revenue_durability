# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
data_dict = pd.read_csv('data/data_dictionary.csv')
dim_month = pd.read_csv('data/dim_month.csv')
dim_plan = pd.read_csv('data/dim_plan.csv')
dim_user = pd.read_csv('data/dim_user.csv')
dim_fact_table = pd.read_csv('data/fact_user_month.csv')

# %%
data_dict.head(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/lightening_net_case_study/.venv/lib/python3.14/site-packages/IPython/core/formatters.py:770, in __call__(self, obj)
#
# File ~/Desktop/lightening_net_case_study/.venv/lib/python3.14/site-packages/IPython/lib/pretty.py:420, in pretty(self, obj)
#
# File ~/Desktop/lightening_net_case_study/.venv/lib/python3.14/site-packages/IPython/lib/pretty.py:795, in _repr_pprint(obj, p, cycle)
#
# File ~/Desktop/lightening_net_case_study/.venv/lib/python3.14/site-packages/pandas/core/frame.py:1201, in __repr__(self)
#
# ...
