# %%
import sys
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import seaborn as sns
#       4 import matplotlib as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
data_dict = pd.read_csv('data/data_dictionary.csv')
dim_month = pd.read_csv('data/dim_month.csv')
dim_plan = pd.read_csv('data/dim_plan.csv')
dim_user = pd.read_csv('data/dim_user.csv')
dim_fact_table = pd.read_csv('data/fact_user_month.csv')

# %%
data_dict.head(5)
# Out:
#              table      field  \
# 0  fact_user_month      month
# 1  fact_user_month    user_id
# 2  fact_user_month    plan_id
# 3  fact_user_month      seats
# 4  fact_user_month  is_active
#
#                                          description
# 0  Month start date (YYYY-MM-01). Grain: user_id ...
# 1                            Unique user/account id.
# 2      FK to dim_plan. Plan active during the month.
# 3           Seat count for Team/Enterprise accounts.
# 4            1 if account active this month, else 0.
